# %%
import tensorflow as tf
print tf.Session().run(tf.constant('Hello, World!'))
print 'TensorFlow version: ' + tf.__version__
# Out:
# Hello, World!
# TensorFlow version: 1.8.0

# %%
# %%HTML
# <a target='_blank' href='https://user-images.githubusercontent.com/10505790/42124559-a4b0ec2a-7c19-11e8-81dd-fbf811c4fc23.png'>
# <img width='200' src='https://user-images.githubusercontent.com/10505790/42124559-a4b0ec2a-7c19-11e8-81dd-fbf811c4fc23.png'/></a>
# <a target='_blank' href='https://user-images.githubusercontent.com/10505790/42728552-57083704-8771-11e8-8822-2bff7c85ed75.jpg'>
# <img width='300' src='https://user-images.githubusercontent.com/10505790/42728552-57083704-8771-11e8-8822-2bff7c85ed75.jpg'/></a>
# Out:
# <a target='_blank' href='https://user-images.githubusercontent.com/10505790/42124559-a4b0ec2a-7c19-11e8-81dd-fbf811c4fc23.png'>
# <img width='200' src='https://user-images.githubusercontent.com/10505790/42124559-a4b0ec2a-7c19-11e8-81dd-fbf811c4fc23.png'/></a>
# <a target='_blank' href='https://user-images.githubusercontent.com/10505790/42728552-57083704-8771-11e8-8822-2bff7c85ed75.jpg'>
# <img width='300' src='https://user-images.githubusercontent.com/10505790/42728552-57083704-8771-11e8-8822-2bff7c85ed75.jpg'/></a>

# %%
import IPython
IPython.display.Audio("binaries/HelloWorld.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib inline
from ipywidgets import interactive, fixed
from matplotlib import pyplot as plt
print "Imports complete"
# Out:
# Imports complete

# %%
from ipywidgets import interact, interactive
from IPython.display import clear_output, display, HTML
import numpy as np
from scipy import integrate
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import cnames
from matplotlib import animation
print "More imports complete"
# Out:
# More imports complete

# %%
def solve_lorenz(N=10, angle=0.0, max_time=4.0, sigma=10.0, beta=8./3, rho=28.0):

    fig = plt.figure()
    ax = fig.add_axes([0, 0, 1, 1], projection='3d')
    ax.axis('off')

    # prepare the axes limits
    ax.set_xlim((-25, 25))
    ax.set_ylim((-35, 35))
    ax.set_zlim((5, 55))
    
    def lorenz_deriv(x_y_z, t0, sigma=sigma, beta=beta, rho=rho):
        """Compute the time-derivative of a Lorenz system."""
        x, y, z = x_y_z
        return [sigma * (y - x), x * (rho - z) - y, x * y - beta * z]

    # Choose random starting points, uniformly distributed from -15 to 15
    np.random.seed(1)
    x0 = -15 + 30 * np.random.random((N, 3))

    # Solve for the trajectories
    t = np.linspace(0, max_time, int(250*max_time))
    x_t = np.asarray([integrate.odeint(lorenz_deriv, x0i, t)
                      for x0i in x0])
    
    # choose a different color for each trajectory
    colors = plt.cm.viridis(np.linspace(0, 1, N))

    for i in range(N):
        x, y, z = x_t[i,:,:].T
        lines = ax.plot(x, y, z, '-', c=colors[i])
        plt.setp(lines, linewidth=2)

    ax.view_init(30, angle)
    plt.show()

    return t, x_t

# %% [markdown]
# ###### e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# $e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$
# ###### e^{\pi i} + 1 = 0
# $e^{\pi i} + 1 = 0$

# %% [markdown]
# ###### begin{align}
# ###### dot{x} & = \sigma(y-x) \\
# ###### dot{y} & = \rho x - y - xz \\
# ###### dot{z} & = -\beta z + xy
# ###### end{align}
# \begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{align}

# %%
t, x_t = solve_lorenz(angle=1, N=12)

# %%
from sympy import *
sympify('2**2 / 3 + 5')
# Out:
# 19/3
